# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model

llm = init_chat_model("openai:gpt-4o", temperature=0)

# %%
file_search_tool = {
  "type": "file_search",
  "vector_store_ids": ["vs_694ecf74ead881919d6ceea04b26a207"],
}

llm_with_tools = llm.bind_tools([file_search_tool])

# %%
response = llm_with_tools.invoke("Como mejoro el rendimiento de mi website?")
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# [{'id': 'fs_000827bcc23dec1c00694ecfaabab08196aa363ac9b12fe5a0', 'queries': ['mejorar el rendimiento de un website'], 'status': 'completed', 'type': 'file_search_call'}, {'type': 'text', 'text': 'Para mejorar el rendimiento de tu website, puedes seguir estas recomendaciones:\n\n1. **Optimización de Imágenes**: Asegúrate de que las imágenes estén correctamente dimensionadas y utiliza formatos de próxima generación como WebP para reducir el tiempo de carga.\n\n2. **Eliminar Recursos que Bloquean el Renderizado**: Minimiza el uso de scripts y estilos que bloquean la carga de la página para mejorar la velocidad de renderizado.\n\n3. **Minificar JavaScript y CSS**: Reduce el tamaño de los archivos JavaScript y CSS eliminando espacios en blanco y comentarios innecesarios.\n\n4. **Habilitar la Compresión de Texto**: Utiliza la compresión Gzip para reducir el tamaño de los archivos enviados desde el servidor.\n\n5. **Implementar AMP (Accelerated Mobile Pages)**: Considera usar AMP para crear páginas que carguen casi instantáneamente, mejorando la experiencia del usuario.\n\n6. **Establecer Presupuestos de Rendimiento**: Define límites en métricas clave de rendimiento para asegurarte de que tu sitio se mantenga rápido.\n\n7. **Utilizar Herramientas de Medición**: Herramientas como Lighthouse y PageSpeed Insights pueden ayudarte a identificar áreas de mejora y medir el rendimiento de tu sitio.\n\nImplementar estas prácticas puede ayudarte a mejorar significativamente la velocidad y el rendimiento de tu sitio web.', 'annotations': [{'file_id': 'file-PT8fR9N1WpPMkL1mrptehg', 'filename': 'Mobile_Site_Speed_Playbook.pdf', 'type': 'file_citation', 'file_index': 260}, {'file_id': 'file-PT8fR9N1WpPMkL1mrptehg', 'filename': 'Mobile_Site_Speed_Playbook.pdf', 'type': 'file_citation', 'file_index': 429}, {'file_id': 'file-PT8fR9N1WpPMkL1mrptehg', 'filename': 'Mobile_Site_Speed_Playbook.pdf', 'type': 'file_citation', 'file_index': 573}, {'file_id': 'file-PT8fR9N1WpPMkL1mrptehg', 'filename': 'Mobile_Site_Speed_Playbook.pdf', 'type': 'file_citation', 'file_index': 709}, {'file_id': 'file-PT8fR9N1WpPMkL1mrptehg', 'filename': 'Mobile_Site_Speed_Playbook.pdf', 'type': 'file_citation', 'file_index': 872}, {'file_id': 'file-PT8fR9N1WpPMkL1mrptehg', 'filename': 'Mobile_Site_Speed_Playbook.pdf', 'type': 'file_citation', 'file_index': 1020}, {'file_id': 'file-PT8fR9N1WpPMkL1mrptehg', 'filename': 'Mobile_Site_Speed_Playbook.pdf', 'type': 'file_citation', 'file_index': 1195}], 'id': 'msg_000827bcc23dec1c00694ecfad905c8196b6cf23929dfd2d63'}]
