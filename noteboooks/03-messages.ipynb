# %%
from langchain_core.messages import AIMessage, SystemMessage, HumanMessage


ai_message = AIMessage(content="Message from AI")
ai_message.text
# Out:
# 'Message from AI'

# %%
history = [ai_message]
for m in history:
  m.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Message from AI

# %%
[1,2,3] + [4,5,6]
# Out:
# [1, 2, 3, 4, 5, 6]
